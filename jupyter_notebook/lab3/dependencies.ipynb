# %% [markdown]
# **Install required system packages**

# %%
# !apt install ffmpeg python3-scipy python3-sklearn python3-matplotlib
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# ffmpeg is already the newest version (7:4.4.1-3ubuntu5).
# python3-matplotlib is already the newest version (3.5.1-2build1).
# python3-matplotlib set to manually installed.
# python3-scipy is already the newest version (1.8.0-1exp2ubuntu1).
# python3-sklearn is already the newest version (0.23.2-5ubuntu6).
# 0 upgraded, 0 newly installed, 0 to remove and 246 not upgraded.

# %% [markdown]
# **Install specially cross-compiled tflite_runtime (the PyPI wheel uses instructions not available on this ARM core...)**

# %%
# !pip install --no-deps https://github.com/DeepWok/pynqchat/raw/refs/heads/main/talkbot/tflite_runtime-2.14.1-cp310-cp310-linux_armv7l.whl
# Out:
# Collecting tflite-runtime==2.14.1
#   ERROR: HTTP error 404 while getting https://github.com/DeepWok/pynqchat/raw/refs/heads/main/talkbot/tflite_runtime-2.14.1-cp310-cp310-linux_armv7l.whl
# ERROR: Could not install requirement tflite-runtime==2.14.1 from https://github.com/DeepWok/pynqchat/raw/refs/heads/main/talkbot/tflite_runtime-2.14.1-cp310-cp310-linux_armv7l.whl because of HTTP error 404 Client Error: Not Found for url: https://github.com/DeepWok/pynqchat/raw/refs/heads/main/talkbot/tflite_runtime-2.14.1-cp310-cp310-linux_armv7l.whl for URL https://github.com/DeepWok/pynqchat/raw/refs/heads/main/talkbot/tflite_runtime-2.14.1-cp310-cp310-linux_armv7l.whl

# %% [markdown]
# **Install other python packages**

# %%
# !pip install --no-deps -r https://github.com/DeepWok/pynqchat/raw/refs/heads/main/talkbot/requirements.txt
# Out:
# ERROR: 404 Client Error: Not Found for url: https://github.com/DeepWok/pynqchat/raw/refs/heads/main/talkbot/requirements.txt
